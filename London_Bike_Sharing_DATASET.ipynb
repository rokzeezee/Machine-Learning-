# %% [markdown]
# <a href="https://colab.research.google.com/github/rokzeezee/Machine-Learning-/blob/main/London_Bike_Sharing_DATASET.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df = pd.read_csv('/content/london_merged.csv')
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.dtypes
# Out:
# timestamp        object
# cnt               int64
# t1              float64
# t2              float64
# hum             float64
# wind_speed      float64
# weather_code    float64
# is_holiday      float64
# is_weekend      float64
# season          float64
# dtype: object

# %%
df.shape
# Out:
# (17414, 10)

# %%
df['weather_code'].value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather_code, dtype: int64

# %%
df['weather_code'].nunique()
# Out:
# 7

# %%
df.columns
# Out:
# Index(['timestamp', 'cnt', 't1', 't2', 'hum', 'wind_speed', 'weather_code',
#        'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
df.rename(columns = {'timestamp' : 'Time', 'cnt' : 'count', 't1' : 'Temp_real_c', 't2' : 'Temp_feels_like_C', 'hum' : 'humidity_percent', 'wind_speed' : 'wind_speed_kph', 'weather_code' : 'weather',
       'is_holiday' :'Holiday', 'is_weekend' : 'Weekend', 'season' : 'Season'} , inplace = True)

# %%
df
# Out:
#                       Time  count  Temp_real_c  Temp_feels_like_C  \
# 0      2015-01-04 00:00:00    182          3.0                2.0
# 1      2015-01-04 01:00:00    138          3.0                2.5
# 2      2015-01-04 02:00:00    134          2.5                2.5
# 3      2015-01-04 03:00:00     72          2.0                2.0
# 4      2015-01-04 04:00:00     47          2.0                0.0
# ...                    ...    ...          ...                ...
# 17409  2017-01-03 19:00:00   1042          5.0                1.0
# 17410  2017-01-03 20:00:00    541          5.0                1.0
# 17411  2017-01-03 21:00:00    337          5.5                1.5
# 17412  2017-01-03 22:00:00    224          5.5                1.5
# 17413  2017-01-03 23:00:00    139          5.0                1.0
#
#        humidity_percent  wind_speed_kph  weather  Holiday  Weekend  Season
# 0                  93.0             6.0      3.0      0.0      1.0     3.0
# ...

# %%
df['humidity_percent']=df['humidity_percent']/100

# %%
df
# Out:
#                       Time  count  Temp_real_c  Temp_feels_like_C  \
# 0      2015-01-04 00:00:00    182          3.0                2.0
# 1      2015-01-04 01:00:00    138          3.0                2.5
# 2      2015-01-04 02:00:00    134          2.5                2.5
# 3      2015-01-04 03:00:00     72          2.0                2.0
# 4      2015-01-04 04:00:00     47          2.0                0.0
# ...                    ...    ...          ...                ...
# 17409  2017-01-03 19:00:00   1042          5.0                1.0
# 17410  2017-01-03 20:00:00    541          5.0                1.0
# 17411  2017-01-03 21:00:00    337          5.5                1.5
# 17412  2017-01-03 22:00:00    224          5.5                1.5
# 17413  2017-01-03 23:00:00    139          5.0                1.0
#
#        humidity_percent  wind_speed_kph  weather  Holiday  Weekend  Season
# 0                 0.930             6.0      3.0      0.0      1.0     3.0
# ...

# %%
df['Season'].nunique()
# Out:
# 4

# %%
df['Season'].value_counts()
# Out:
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: Season, dtype: int64

# %%
Season_dict = { '0.0' : 'Spring', '1.0' : 'Summer' , '3.0' : 'winter' , '2.0' : 'Autum'}
Season_dict
# Out:
# {'0.0': 'Spring', '1.0': 'Summer', '3.0': 'winter', '2.0': 'Autum'}

# %%
df['weather'].value_counts()
# Out:
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: weather, dtype: int64

# %%
weather_dic = { '1.0' :'clear','2.0' :'Scattered Clouds',  '3.0' : 'Broken clouds', '4.0': 'Clouds', '7.0' : 'Rain' , '10.0' : 'Rain with Thunderstorm' , '26.0' : 'Snowfall'}
weather_dic
# Out:
# {'1.0': 'clear',
#  '2.0': 'Scattered Clouds',
#  '3.0': 'Broken clouds',
#  '4.0': 'Clouds',
#  '7.0': 'Rain',
#  '10.0': 'Rain with Thunderstorm',
#  '26.0': 'Snowfall'}

# %%
df['Season'].dtypes
# Out:
# dtype('float64')

# %%
df['Season'].astype(str)
# Out:
# 0        3.0
# 1        3.0
# 2        3.0
# 3        3.0
# 4        3.0
#         ...
# 17409    3.0
# 17410    3.0
# 17411    3.0
# 17412    3.0
# 17413    3.0
# Name: Season, Length: 17414, dtype: object

# %%
df['Season']=df['Season'].astype(str)

# %%
df['Season'].map(Season_dict).value_counts()
# Out:
# Spring    4394
# Summer    4387
# winter    4330
# Autum     4303
# Name: Season, dtype: int64

# %%
df['Season']=df['Season'].map(Season_dict)

# %%
df
# Out:
#                       Time  count  Temp_real_c  Temp_feels_like_C  \
# 0      2015-01-04 00:00:00    182          3.0                2.0
# 1      2015-01-04 01:00:00    138          3.0                2.5
# 2      2015-01-04 02:00:00    134          2.5                2.5
# 3      2015-01-04 03:00:00     72          2.0                2.0
# 4      2015-01-04 04:00:00     47          2.0                0.0
# ...                    ...    ...          ...                ...
# 17409  2017-01-03 19:00:00   1042          5.0                1.0
# 17410  2017-01-03 20:00:00    541          5.0                1.0
# 17411  2017-01-03 21:00:00    337          5.5                1.5
# 17412  2017-01-03 22:00:00    224          5.5                1.5
# 17413  2017-01-03 23:00:00    139          5.0                1.0
#
#        humidity_percent  wind_speed_kph  weather  Holiday  Weekend  Season
# 0                 0.930             6.0      3.0      0.0      1.0  winter
# ...

# %%
df['weather']=df['weather'].astype(str).map(weather_dic)

# %%
df
# Out:
#                       Time  count  Temp_real_c  Temp_feels_like_C  \
# 0      2015-01-04 00:00:00    182          3.0                2.0
# 1      2015-01-04 01:00:00    138          3.0                2.5
# 2      2015-01-04 02:00:00    134          2.5                2.5
# 3      2015-01-04 03:00:00     72          2.0                2.0
# 4      2015-01-04 04:00:00     47          2.0                0.0
# ...                    ...    ...          ...                ...
# 17409  2017-01-03 19:00:00   1042          5.0                1.0
# 17410  2017-01-03 20:00:00    541          5.0                1.0
# 17411  2017-01-03 21:00:00    337          5.5                1.5
# 17412  2017-01-03 22:00:00    224          5.5                1.5
# 17413  2017-01-03 23:00:00    139          5.0                1.0
#
#        humidity_percent  wind_speed_kph           weather  Holiday  Weekend  \
# 0                 0.930             6.0     Broken clouds      0.0      1.0
# ...

# %%
df.to_excel('London_bike_Data.xlsx' , sheet_name= 'Data')
